# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist, fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical

# %%
# Load MNIST and MNIST Fashion datasets
(x_train_mnist, y_train_mnist), (x_test_mnist, y_test_mnist) = mnist.load_data()
(x_train_fashion, y_train_fashion), (x_test_fashion, y_test_fashion) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
# Normalize the data
x_train_mnist = x_train_mnist / 255.0
x_test_mnist = x_test_mnist / 255.0
x_train_fashion = x_train_fashion / 255.0
x_test_fashion = x_test_fashion / 255.0

# %%
# One-hot encode the target labels
y_train_mnist = to_categorical(y_train_mnist, num_classes=10)
y_test_mnist = to_categorical(y_test_mnist, num_classes=10)
y_train_fashion = to_categorical(y_train_fashion, num_classes=10)
y_test_fashion = to_categorical(y_test_fashion, num_classes=10)

# Define and compile the models
model_single = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(10, activation='softmax')
])
model_single.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

model_mlp = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])
model_mlp.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

model_dnn = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(256, activation='relu'),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])
model_dnn.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train and evaluate the models
print("MNIST Dataset:")
print("Single Layer Network:")
model_single.fit(x_train_mnist, y_train_mnist, epochs=10, batch_size=32, validation_data=(x_test_mnist, y_test_mnist))
model_single.evaluate(x_test_mnist, y_test_mnist)

print("Multi-Layer Perceptron (MLP):")
model_mlp.fit(x_train_mnist, y_train_mnist, epochs=10, batch_size=32, validation_data=(x_test_mnist, y_test_mnist))
model_mlp.evaluate(x_test_mnist, y_test_mnist)

print("Fully Connected Deep Neural Network (DNN):")
model_dnn.fit(x_train_mnist, y_train_mnist, epochs=10, batch_size=32, validation_data=(x_test_mnist, y_test_mnist))
model_dnn.evaluate(x_test_mnist, y_test_mnist)

print("MNIST Fashion Dataset:")
print("Single Layer Network:")
model_single.fit(x_train_fashion, y_train_fashion, epochs=10, batch_size=32, validation_data=(x_test_fashion, y_test_fashion))
model_single.evaluate(x_test_fashion, y_test_fashion)

print("Multi-Layer Perceptron (MLP):")
model_mlp.fit(x_train_fashion, y_train_fashion, epochs=10, batch_size=32, validation_data=(x_test_fashion, y_test_fashion))
model_mlp.evaluate(x_test_fashion, y_test_fashion)

print("Fully Connected Deep Neural Network (DNN):")
model_dnn.fit(x_train_fashion, y_train_fashion, epochs=10, batch_size=32, validation_data=(x_test_fashion, y_test_fashion))
model_dnn.evaluate(x_test_fashion, y_test_fashion)
# Out:
# MNIST Dataset:
# Single Layer Network:
# Epoch 1/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4702 - accuracy: 0.8763 - val_loss: 0.3063 - val_accuracy: 0.9151
# Epoch 2/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3037 - accuracy: 0.9151 - val_loss: 0.2832 - val_accuracy: 0.9220
# Epoch 3/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2832 - accuracy: 0.9208 - val_loss: 0.2747 - val_accuracy: 0.9241
# Epoch 4/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2729 - accuracy: 0.9234 - val_loss: 0.2698 - val_accuracy: 0.9250
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2660 - accuracy: 0.9264 - val_loss: 0.2703 - val_accuracy: 0.9265
# Epoch 6/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2621 - accuracy: 0.9267 - val_loss: 0.2641 - val_accuracy: 0.9269
# Epoch 7/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2581 - accuracy: 0.9283 - val_loss: 0.2717 - val_accuracy: 0.9256
# Epoch 8/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2556 - accuracy: 0.9297 - val_loss: 0.2656 - val_accuracy: 0.9268
# Epoch 9/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2528 - accuracy: 0.9303 - val_loss: 0.2654 - val_accuracy: 0.9256
# Epoch 10/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2511 - accuracy: 0.9308 - val_loss: 0.2647 - val_accuracy: 0.9272
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2647 - accuracy: 0.9272
# Multi-Layer Perceptron (MLP):
# Epoch 1/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2400 - accuracy: 0.9294 - val_loss: 0.1448 - val_accuracy: 0.9571
# Epoch 2/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1006 - accuracy: 0.9699 - val_loss: 0.0946 - val_accuracy: 0.9689
# Epoch 3/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0697 - accuracy: 0.9780 - val_loss: 0.0826 - val_accuracy: 0.9752
# Epoch 4/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0519 - accuracy: 0.9835 - val_loss: 0.0875 - val_accuracy: 0.9732
# Epoch 5/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0412 - accuracy: 0.9865 - val_loss: 0.0860 - val_accuracy: 0.9752
# Epoch 6/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0357 - accuracy: 0.9887 - val_loss: 0.0895 - val_accuracy: 0.9747
# Epoch 7/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0288 - accuracy: 0.9900 - val_loss: 0.0840 - val_accuracy: 0.9781
# Epoch 8/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0246 - accuracy: 0.9920 - val_loss: 0.0936 - val_accuracy: 0.9767
# Epoch 9/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0215 - accuracy: 0.9930 - val_loss: 0.1061 - val_accuracy: 0.9747
# Epoch 10/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0182 - accuracy: 0.9942 - val_loss: 0.1122 - val_accuracy: 0.9754
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1122 - accuracy: 0.9754
# Fully Connected Deep Neural Network (DNN):
# Epoch 1/10
# 1875/1875 [==============================] - 13s 6ms/step - loss: 0.2158 - accuracy: 0.9356 - val_loss: 0.1048 - val_accuracy: 0.9673
# Epoch 2/10
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0944 - accuracy: 0.9711 - val_loss: 0.0854 - val_accuracy: 0.9757
# Epoch 3/10
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0650 - accuracy: 0.9803 - val_loss: 0.0879 - val_accuracy: 0.9745
# Epoch 4/10
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.0499 - accuracy: 0.9844 - val_loss: 0.0969 - val_accuracy: 0.9736
# Epoch 5/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0405 - accuracy: 0.9872 - val_loss: 0.0902 - val_accuracy: 0.9745
# Epoch 6/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0337 - accuracy: 0.9894 - val_loss: 0.0894 - val_accuracy: 0.9767
# Epoch 7/10
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0292 - accuracy: 0.9903 - val_loss: 0.0751 - val_accuracy: 0.9786
# Epoch 8/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0234 - accuracy: 0.9925 - val_loss: 0.0928 - val_accuracy: 0.9790
# Epoch 9/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0225 - accuracy: 0.9927 - val_loss: 0.1005 - val_accuracy: 0.9778
# Epoch 10/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0206 - accuracy: 0.9934 - val_loss: 0.0895 - val_accuracy: 0.9794
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0895 - accuracy: 0.9794
# MNIST Fashion Dataset:
# Single Layer Network:
# Epoch 1/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 1.4049 - accuracy: 0.6953 - val_loss: 0.7920 - val_accuracy: 0.7760
# Epoch 2/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.6322 - accuracy: 0.8035 - val_loss: 0.6126 - val_accuracy: 0.8072
# Epoch 3/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.5223 - accuracy: 0.8271 - val_loss: 0.5559 - val_accuracy: 0.8191
# Epoch 4/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4751 - accuracy: 0.8393 - val_loss: 0.5064 - val_accuracy: 0.8302
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4497 - accuracy: 0.8464 - val_loss: 0.5188 - val_accuracy: 0.8260
# Epoch 6/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4342 - accuracy: 0.8505 - val_loss: 0.4963 - val_accuracy: 0.8359
# Epoch 7/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4231 - accuracy: 0.8544 - val_loss: 0.4762 - val_accuracy: 0.8377
# Epoch 8/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4152 - accuracy: 0.8576 - val_loss: 0.4629 - val_accuracy: 0.8424
# Epoch 9/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4088 - accuracy: 0.8594 - val_loss: 0.4602 - val_accuracy: 0.8386
# Epoch 10/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4038 - accuracy: 0.8602 - val_loss: 0.4722 - val_accuracy: 0.8394
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4722 - accuracy: 0.8394
# Multi-Layer Perceptron (MLP):
# Epoch 1/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.5313 - accuracy: 0.8183 - val_loss: 0.4506 - val_accuracy: 0.8313
# Epoch 2/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3754 - accuracy: 0.8653 - val_loss: 0.3941 - val_accuracy: 0.8585
# Epoch 3/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3410 - accuracy: 0.8753 - val_loss: 0.3898 - val_accuracy: 0.8628
# Epoch 4/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3187 - accuracy: 0.8807 - val_loss: 0.3675 - val_accuracy: 0.8707
# Epoch 5/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3018 - accuracy: 0.8895 - val_loss: 0.3456 - val_accuracy: 0.8740
# Epoch 6/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2879 - accuracy: 0.8931 - val_loss: 0.3546 - val_accuracy: 0.8755
# Epoch 7/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2744 - accuracy: 0.8971 - val_loss: 0.3558 - val_accuracy: 0.8726
# Epoch 8/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2679 - accuracy: 0.9000 - val_loss: 0.3558 - val_accuracy: 0.8755
# Epoch 9/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2561 - accuracy: 0.9048 - val_loss: 0.3568 - val_accuracy: 0.8743
# Epoch 10/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2479 - accuracy: 0.9066 - val_loss: 0.3568 - val_accuracy: 0.8770
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3568 - accuracy: 0.8770
# Fully Connected Deep Neural Network (DNN):
# Epoch 1/10
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.4986 - accuracy: 0.8236 - val_loss: 0.4151 - val_accuracy: 0.8525
# Epoch 2/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.3578 - accuracy: 0.8682 - val_loss: 0.3850 - val_accuracy: 0.8598
# Epoch 3/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.3218 - accuracy: 0.8815 - val_loss: 0.3571 - val_accuracy: 0.8717
# Epoch 4/10
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.2984 - accuracy: 0.8892 - val_loss: 0.3488 - val_accuracy: 0.8732
# Epoch 5/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.2824 - accuracy: 0.8952 - val_loss: 0.3482 - val_accuracy: 0.8704
# Epoch 6/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.2684 - accuracy: 0.8989 - val_loss: 0.3440 - val_accuracy: 0.8775
# Epoch 7/10
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.2592 - accuracy: 0.9021 - val_loss: 0.3354 - val_accuracy: 0.8814
# Epoch 8/10
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.2483 - accuracy: 0.9070 - val_loss: 0.3427 - val_accuracy: 0.8793
# Epoch 9/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.2391 - accuracy: 0.9098 - val_loss: 0.3495 - val_accuracy: 0.8831
# Epoch 10/10
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.2319 - accuracy: 0.9126 - val_loss: 0.3464 - val_accuracy: 0.8791
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3464 - accuracy: 0.8791
# [0.3463606834411621, 0.8791000247001648]
